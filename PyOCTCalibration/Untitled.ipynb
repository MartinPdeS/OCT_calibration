# %%
'''_____Standard imports_____'''
import numpy as np
import json
import sys
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

'''_____Project imports_____'''
from toolbox.PySpectra import Spectra
from toolbox.parsing import parse_arguments
from toolbox.spectra_processing import compute_dispersion, k_linearization, shift_spectra, compensate_dispersion
from toolbox.loadings import load_data
from toolbox.plottings import dB_plot
from toolbox.maths import spectra2aline, apodization, unwrap_phase

# %%
directory = "/Volumes/Untitled/Calibrations/Bscan/papier_0.raw"

# %%
def load_Bscan_spectra(file_dir, block_start=276, block_end = 632084, shape1=1024, shape2=1024):

    data = np.fromfile(file_dir, dtype = np.uint16)


    #block_start = 284
    block_end = block_start + 1024*1024
    #test = len(data[284:])
    #print(test)

    block_data = data[block_start: block_end]
    Bscan_spectra = block_data.reshape([1024,1024])
    return Bscan_spectra

# %%
Bscan = load_Bscan_spectra(directory)

# %%
Bscan = np.array(Bscan).T
dBscan = 10*np.log(Bscan)

# %%
plt.imshow(dBscan, cmap='gray')
# Out:
# <img src="data:image/png;base64,..." width="640">
