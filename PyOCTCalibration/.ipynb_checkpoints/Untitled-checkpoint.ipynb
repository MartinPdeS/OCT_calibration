# %%
'''_____Standard imports_____'''
import numpy as np
import json
import sys
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

'''_____Project imports_____'''
from toolbox.PySpectra import Spectra
from toolbox.parsing import parse_arguments
from toolbox.spectra_processing import compute_dispersion, k_linearization, shift_spectra, compensate_dispersion
from toolbox.loadings import load_data
from toolbox.plottings import dB_plot
from toolbox.maths import spectra2aline, apodization, unwrap_phase

# %%
calibration_dir = "/Volumes/Untitled/Calibrations/04-06-1/"

Mirror1 = Spectra(data_dir=calibration_dir + "mirror1.txt",
                  background_dir=calibration_dir + "dark_not.txt",
                  sample_dir=calibration_dir + "dark_sample1.txt",
                  ref_dir=calibration_dir + "dark_ref.txt")

Mirror1.load_data()
Mirror1.process_data(plot=False)
Mirror1.get_phase()

Mirror2 = Spectra(data_dir=calibration_dir + "mirror2.txt",
                  background_dir=calibration_dir + "dark_not.txt",
                  sample_dir=calibration_dir + "dark_sample2.txt",
                  ref_dir=calibration_dir + "dark_ref.txt")

Mirror2.load_data()
Mirror2.process_data(plot=False)
Mirror2.get_phase()
# Out:
# /usr/local/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]

# %%
# %matplotlib qt 
plt.plot(Mirror2.phase,'r')
plt.plot(Mirror1.phase,'b')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9a35bd1e2fb1> in <module>()
#       1 get_ipython().run_line_magic('matplotlib', 'qt')
# ----> 2 plt.plot(Mirror2.phase,'r')
#       3 plt.plot(Mirror1.phase,'b')
#
# NameError: name 'plt' is not defined

# %%
p1 = unwrap(angle(hilbert(s1)));
p2 = unwrap(angle(hilbert(s2)));
# %setting first phase value to 0
p1 = p1-p1(1);
p2 = p2-p2(1);

# %phase linearization
x       = 1:length(s1);                                         %index vector
p_lin   = (p1+p2)/2;                                            %linear phase component (from signal)

# %additional fitting step to increase stability in presence of noise (optional)
pfit    = fit(x',p_lin,'poly5','weights',w,'normalize','on');   %fitting p_lin data for smoother curve
p_lin   = pfit(x);                                              %re-defining p_lin

# %defining fractional indices
ft      = fit(p_lin,x','poly5','weights',w,'normalize','on');   %linear phase (signal) to index mapping function
x_new   = ft(linspace(p_lin(1),p_lin(end),length(p_lin)));      %fractional indices for actually linear phase

# %k-linearizing signal
s12  = spline(x,s1,x_new);   %interpolation (cubic spline)
s22  = spline(x,s2,x_new);   %interpolation (cubic spline)

              
              
              
              
                  coefs = np.polynomial.polynomial.polyfit(x, y, order, w=weight)
    ffit = np.poly1d(coefs[::-1])
# Out:
#   File "<ipython-input-3-0525f452f92e>", line 8
#     x       = 1:length(s1);                                         %index vector
#                ^
# SyntaxError: invalid syntax

# %%
p1 = unwrap_phase(Mirror1.sub_raw)
p2 = unwrap_phase(Mirror2.sub_raw)
p1 = p1-p1[0]
p2 = p2-p2[0]

x = np.arange(len(Mirror1.sub_raw))

P_lin0 = (p1 + p2)/2

coefs1 = np.polynomial.polynomial.polyfit(x, P_lin0, 5)
ffit1 = np.poly1d(coefs1[::-1])
P_lin1 = ffit1(x)


coefs2 = np.polynomial.polynomial.polyfit(P_lin1, x, 5)
ffit2 = np.poly1d(coefs2[::-1])
x_new = ffit2( np.linspace( P_lin1[0], P_lin1[-1], len(P_lin1) ) )



#interpolation = interp1d(x, Mirror1.sub_raw, kind=5)
#a=interpolation(x_new[:-1])

# %%
# %matplotlib qt 
plt.plot(spectra2aline( Mirror1.sub_raw),'b')
plt.plot(spectra2aline(a),'r')
plt.show()

# %%
# %matplotlib qt 
plt.plot(x, P_lin1,'r')
plt.show()

# %%
# %matplotlib notebook
plt.plot(x_new)
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x_new
# Out:
# array([8.07463611e-01, 2.03351577e+00, 3.25845249e+00, ...,
#        1.02153603e+03, 1.02248212e+03, 1.02342908e+03])
